# %% [markdown]
# <a href="https://colab.research.google.com/github/esther3442/test2/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("나는 김대원")
# Out:
# 나는 김대원
